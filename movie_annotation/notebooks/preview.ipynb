# %%
"""Load and preview feature dataframes for all movies."""

import pandas as pd
import numpy as np
from pathlib import Path

OUTPUT_DIR = Path("../output")

movies = sorted(p.parent.name for p in OUTPUT_DIR.glob("*/features.parquet"))

for movie in movies:
    df = pd.read_parquet(OUTPUT_DIR / movie / "features.parquet")
    emb = np.load(OUTPUT_DIR / movie / "clip_embeddings.npz")

    print(f"=== {movie} ({len(df)} frames) ===")
    # print(df.head())
    print(f"\nClip embeddings: {emb['embeddings'].shape}")
    print(df.describe())
    print()
    break
# Out:
# === The_Present (4877 frames) ===
#
# Clip embeddings: (4877, 512)
#        luminance_mean  contrast_rms  color_r_mean  color_g_mean  color_b_mean  \
# count     4877.000000   4877.000000   4877.000000   4877.000000   4877.000000
# mean         0.481630      0.243717      0.529995      0.469738      0.416938
# std          0.160310      0.057511      0.169933      0.158720      0.149277
# min          0.004615      0.013511      0.004640      0.000696      0.008559
# 25%          0.432377      0.215815      0.478757      0.422731      0.354782
# 50%          0.513009      0.261045      0.573017      0.497877      0.436686
# 75%          0.576490      0.282010      0.622469      0.564479      0.521352
# max          0.921603      0.331082      0.936845      0.920396      0.887554
#
#        saturation_mean  edge_density  spatial_freq_energy      entropy  \
# count      4877.000000   4877.000000          4877.000000  4877.000000
# mean          0.313227      0.057243             0.002144     7.167792
# std           0.140948      0.042286             0.004460     1.268576
# min           0.067475      0.000833             0.000114     0.048223
# 25%           0.231430      0.033216             0.000732     7.225799
# 50%           0.304697      0.048277             0.001047     7.522238
# 75%           0.342503      0.062652             0.001838     7.594840
# max           0.996694      0.230503             0.037335     7.779680
#
#        motion_energy  ...  timestamp_s      n_faces  face_area_frac  \
# count    4877.000000  ...  4877.000000  4877.000000     4877.000000
# mean        1.219981  ...   101.604158     0.408448        0.051821
# std         2.403661  ...    58.679234     0.503143        0.091705
# min         0.000000  ...     0.000000     0.000000        0.000000
# 25%         0.110808  ...    50.802079     0.000000        0.000000
# 50%         0.305560  ...   101.604158     0.000000        0.000000
# 75%         1.130470  ...   152.406237     1.000000        0.093815
# max        21.000553  ...   203.208316     2.000000        0.625781
#
#         depth_mean    depth_std  depth_range    n_objects  \
# count  4877.000000  4877.000000  4877.000000  4877.000000
# mean     15.725908     9.677735    33.757774     3.133074
# std       2.731578     3.897773    11.151256     2.737663
# min       5.564843     2.328170    11.952299     0.000000
# 25%      14.113990     7.051474    26.835346     1.000000
# 50%      15.466784     9.578691    31.171080     3.000000
# 75%      17.642260    11.294737    39.071171     4.000000
# max      27.531563    27.530659    82.290489    31.000000
#
#        scene_category_score  scene_natural_score  scene_open_score
# count           4877.000000          4877.000000       4877.000000
# mean               0.069893            -0.008965         -0.030070
# std                0.000674             0.015097          0.019264
# min                0.067519            -0.065102         -0.080361
# 25%                0.069490            -0.018118         -0.044011
# 50%                0.069882            -0.009316         -0.028398
# 75%                0.070299            -0.000712         -0.014709
# max                0.071774             0.044451          0.023438
#
# [8 rows x 21 columns]
